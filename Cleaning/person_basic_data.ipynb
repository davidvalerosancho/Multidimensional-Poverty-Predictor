# %%
import pandas as pd

# %%
person_basic = pd.read_csv(r'C:\Users\dvale\TFM\Data\person_basic.csv', low_memory=False) #Column 5 has different types

# %%
person_basic.head()
# Out:
#    RB010 RB020  RB030       RB050  RB050_F RB070  RB070_F  RB080  RB080_F  \
# 0   2019    ES    101   906.15830        1     4        1   1949        1
# 1   2019    ES    102   906.15830        1     2        1   1951        1
# 2   2019    ES    201  1227.68869        1     9        1   1947        1
# 3   2019    ES    202  1227.68869        1     4        1   1959        1
# 4   2019    ES    301  2559.35987        1    11        1   1965        1
#
#    RB090  ...  RL040  RL040_F  RL050 RL050_F  RL060 RL060_F  RL070 RL070_F  \
# 0      1  ...              -2             -2             -2             -2
# 1      2  ...              -2             -2             -2             -2
# 2      2  ...              -2             -2             -2             -2
# 3      1  ...              -2             -2             -2             -2
# 4      2  ...              -2             -2             -2             -2
#
#    vrLOWJOB vrEU2020
# 0         9        0
# 1         9        0
# ...

# %%
person_basic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39852 entries, 0 to 39851
# Data columns (total 37 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   RB010     39852 non-null  int64
#  1   RB020     39852 non-null  object
#  2   RB030     39852 non-null  int64
#  3   RB050     39852 non-null  float64
#  4   RB050_F   39852 non-null  int64
#  5   RB070     39852 non-null  object
#  6   RB070_F   39852 non-null  int64
#  7   RB080     39852 non-null  int64
#  8   RB080_F   39852 non-null  int64
#  9   RB090     39852 non-null  int64
#  10  RB090_F   39852 non-null  int64
#  11  RB200     39852 non-null  int64
#  12  RB200_F   39852 non-null  int64
#  13  RB210     39852 non-null  object
#  14  RB210_F   39852 non-null  int64
#  15  RB220     39852 non-null  object
#  16  RB220_F   39852 non-null  int64
#  17  RB230     39852 non-null  object
#  18  RB230_F   39852 non-null  int64
#  19  RB240     39852 non-null  object
# ...

# %%
person_basic = person_basic.drop(columns=['RB010', 'RB020'])

person_basic.head()
# Out:
#    RB030       RB050  RB050_F RB070  RB070_F  RB080  RB080_F  RB090  RB090_F  \
# 0    101   906.15830        1     4        1   1949        1      1        1
# 1    102   906.15830        1     2        1   1951        1      2        1
# 2    201  1227.68869        1     9        1   1947        1      2        1
# 3    202  1227.68869        1     4        1   1959        1      1        1
# 4    301  2559.35987        1    11        1   1965        1      2        1
#
#    RB200  ...  RL040 RL040_F  RL050 RL050_F  RL060 RL060_F  RL070 RL070_F  \
# 0      1  ...             -2             -2             -2             -2
# 1      1  ...             -2             -2             -2             -2
# 2      1  ...             -2             -2             -2             -2
# 3      1  ...             -2             -2             -2             -2
# 4      1  ...             -2             -2             -2             -2
#
#    vrLOWJOB vrEU2020
# 0         9        0
# ...

# %%
person_basic.rename(columns={'RB030': 'person_id'}, inplace=True)

person_basic.head()
# Out:
#    person_id       RB050  RB050_F RB070  RB070_F  RB080  RB080_F  RB090  \
# 0        101   906.15830        1     4        1   1949        1      1
# 1        102   906.15830        1     2        1   1951        1      2
# 2        201  1227.68869        1     9        1   1947        1      2
# 3        202  1227.68869        1     4        1   1959        1      1
# 4        301  2559.35987        1    11        1   1965        1      2
#
#    RB090_F  RB200  ...  RL040 RL040_F  RL050 RL050_F  RL060 RL060_F  RL070  \
# 0        1      1  ...             -2             -2             -2
# 1        1      1  ...             -2             -2             -2
# 2        1      1  ...             -2             -2             -2
# 3        1      1  ...             -2             -2             -2
# 4        1      1  ...             -2             -2             -2
#
#   RL070_F  vrLOWJOB vrEU2020
# 0      -2         9        0
# 1      -2         9        0
# ...

# %%
person_basic.rename(columns={'RB050_F': 'Individual cross factor value (flag)'}, inplace=True)

factor_flag_dict = {-1: 'Not reported', 1: 'Reported'}

factor_flag_column = []

for element in person_basic['Individual cross factor value (flag)']:
    for key in factor_flag_dict.keys():
        if element == key:
            factor_flag_column.append(factor_flag_dict[key])

person_basic['Individual cross factor value (flag)'] = factor_flag_column

person_basic.head()
# Out:
#    person_id       RB050 Individual cross factor value (flag) RB070  RB070_F  \
# 0        101   906.15830                             Reported     4        1
# 1        102   906.15830                             Reported     2        1
# 2        201  1227.68869                             Reported     9        1
# 3        202  1227.68869                             Reported     4        1
# 4        301  2559.35987                             Reported    11        1
#
#    RB080  RB080_F  RB090  RB090_F  RB200  ...  RL040 RL040_F  RL050 RL050_F  \
# 0   1949        1      1        1      1  ...             -2             -2
# 1   1951        1      2        1      1  ...             -2             -2
# 2   1947        1      2        1      1  ...             -2             -2
# 3   1959        1      1        1      1  ...             -2             -2
# 4   1965        1      2        1      1  ...             -2             -2
#
# ...

# %%
person_basic['Individual cross factor value (flag)'].unique()
# Out:
# array(['Reported'], dtype=object)

# %%
person_basic.rename(columns={'RB050': 'Individual cross factor value'}, inplace=True)

person_basic.head()
# Out:
#    person_id  Individual cross factor value  \
# 0        101                      906.15830
# 1        102                      906.15830
# 2        201                     1227.68869
# 3        202                     1227.68869
# 4        301                     2559.35987
#
#   Individual cross factor value (flag) RB070  RB070_F  RB080  RB080_F  RB090  \
# 0                             Reported     4        1   1949        1      1
# 1                             Reported     2        1   1951        1      2
# 2                             Reported     9        1   1947        1      2
# 3                             Reported     4        1   1959        1      1
# 4                             Reported    11        1   1965        1      2
#
#    RB090_F  RB200  ...  RL040 RL040_F  RL050 RL050_F  RL060 RL060_F  RL070  \
# 0        1      1  ...             -2             -2             -2
# 1        1      1  ...             -2             -2             -2
# ...

# %%
person_basic.rename(columns={'RB070_F': 'Month of birth (flag)'}, inplace=True)

month_flag_dict = {-1: 'Not reported', 1: 'Reported'}

month_flag_column = []

for element in person_basic['Month of birth (flag)']:
    for key in month_flag_dict.keys():
        if element == key:
            month_flag_column.append(month_flag_dict[key])

person_basic['Month of birth (flag)'] = month_flag_column

person_basic.head()
# Out:
#    person_id  Individual cross factor value  \
# 0        101                      906.15830
# 1        102                      906.15830
# 2        201                     1227.68869
# 3        202                     1227.68869
# 4        301                     2559.35987
#
#   Individual cross factor value (flag) RB070 Month of birth (flag)  RB080  \
# 0                             Reported     4              Reported   1949
# 1                             Reported     2              Reported   1951
# 2                             Reported     9              Reported   1947
# 3                             Reported     4              Reported   1959
# 4                             Reported    11              Reported   1965
#
#    RB080_F  RB090  RB090_F  RB200  ...  RL040 RL040_F  RL050 RL050_F  RL060  \
# 0        1      1        1      1  ...             -2             -2
# 1        1      2        1      1  ...             -2             -2
# ...

# %%
person_basic['Month of birth (flag)'].unique()
# Out:
# array(['Reported', 'Not reported'], dtype=object)

# %%
person_basic.rename(columns={'RB070': 'Month of birth'}, inplace=True)

person_basic.head()
# Out:
#    person_id  Individual cross factor value  \
# 0        101                      906.15830
# 1        102                      906.15830
# 2        201                     1227.68869
# 3        202                     1227.68869
# 4        301                     2559.35987
#
#   Individual cross factor value (flag) Month of birth Month of birth (flag)  \
# 0                             Reported              4              Reported
# 1                             Reported              2              Reported
# 2                             Reported              9              Reported
# 3                             Reported              4              Reported
# 4                             Reported             11              Reported
#
#    RB080  RB080_F  RB090  RB090_F  RB200  ...  RL040 RL040_F  RL050 RL050_F  \
# 0   1949        1      1        1      1  ...             -2             -2
# 1   1951        1      2        1      1  ...             -2             -2
# ...

# %%
person_basic.rename(columns={'RB080_F': 'Year of birth (flag)'}, inplace=True)

year_flag_dict = {-1: 'Not reported', 1: 'Reported'}

year_flag_column = []

for element in person_basic['Year of birth (flag)']:
    for key in year_flag_dict.keys():
        if element == key:
            year_flag_column.append(year_flag_dict[key])

person_basic['Year of birth (flag)'] = year_flag_column

person_basic.head()
# Out:
#    person_id  Individual cross factor value  \
# 0        101                      906.15830
# 1        102                      906.15830
# 2        201                     1227.68869
# 3        202                     1227.68869
# 4        301                     2559.35987
#
#   Individual cross factor value (flag) Month of birth Month of birth (flag)  \
# 0                             Reported              4              Reported
# 1                             Reported              2              Reported
# 2                             Reported              9              Reported
# 3                             Reported              4              Reported
# 4                             Reported             11              Reported
#
#    RB080 Year of birth (flag)  RB090  RB090_F  RB200  ...  RL040 RL040_F  \
# 0   1949             Reported      1        1      1  ...             -2
# 1   1951             Reported      2        1      1  ...             -2
# ...

# %%
person_basic['Year of birth (flag)'].unique()
# Out:
# array(['Reported'], dtype=object)

# %%
person_basic.rename(columns={'RB080': 'Year of birth'}, inplace=True)

person_basic.head()
# Out:
#    person_id  Individual cross factor value  \
# 0        101                      906.15830
# 1        102                      906.15830
# 2        201                     1227.68869
# 3        202                     1227.68869
# 4        301                     2559.35987
#
#   Individual cross factor value (flag) Month of birth Month of birth (flag)  \
# 0                             Reported              4              Reported
# 1                             Reported              2              Reported
# 2                             Reported              9              Reported
# 3                             Reported              4              Reported
# 4                             Reported             11              Reported
#
#    Year of birth Year of birth (flag)  RB090  RB090_F  RB200  ...  RL040  \
# 0           1949             Reported      1        1      1  ...
# 1           1951             Reported      2        1      1  ...
# ...

# %%
person_basic.rename(columns={'RB090_F': 'Sex (flag)'}, inplace=True)

sex_flag_dict = {-1: 'Not reported', 1: 'Reported'}

sex_flag_column = []

for element in person_basic['Sex (flag)']:
    for key in sex_flag_dict.keys():
        if element == key:
            sex_flag_column.append(sex_flag_dict[key])

person_basic['Sex (flag)'] = sex_flag_column

person_basic.head()
# Out:
#    person_id  Individual cross factor value  \
# 0        101                      906.15830
# 1        102                      906.15830
# 2        201                     1227.68869
# 3        202                     1227.68869
# 4        301                     2559.35987
#
#   Individual cross factor value (flag) Month of birth Month of birth (flag)  \
# 0                             Reported              4              Reported
# 1                             Reported              2              Reported
# 2                             Reported              9              Reported
# 3                             Reported              4              Reported
# 4                             Reported             11              Reported
#
#    Year of birth Year of birth (flag)  RB090 Sex (flag)  RB200  ...  RL040  \
# 0           1949             Reported      1   Reported      1  ...
# 1           1951             Reported      2   Reported      1  ...
# ...

# %%
person_basic['Sex (flag)'].unique()
# Out:
# array(['Reported'], dtype=object)

# %%
person_basic.rename(columns={'RB090': 'Sex'}, inplace=True)

sex_dict = {1: 'Male', 2: 'Female'}

sex_column = []

for element in person_basic['Sex']:
    for key in sex_dict.keys():
        if element == key:
            sex_column.append(sex_dict[key])

person_basic['Sex'] = sex_column

person_basic[person_basic.columns[1:]].head()
# Out:
#    Individual cross factor value Individual cross factor value (flag)  \
# 0                      906.15830                             Reported
# 1                      906.15830                             Reported
# 2                     1227.68869                             Reported
# 3                     1227.68869                             Reported
# 4                     2559.35987                             Reported
#
#   Month of birth Month of birth (flag)  Year of birth Year of birth (flag)  \
# 0              4              Reported           1949             Reported
# 1              2              Reported           1951             Reported
# 2              9              Reported           1947             Reported
# 3              4              Reported           1959             Reported
# 4             11              Reported           1965             Reported
#
#       Sex Sex (flag)  RB200  RB200_F  ... RL040  RL040_F RL050  RL050_F RL060  \
# ...

# %%
person_basic.rename(columns={'RB200_F': 'Residence in the household (flag)'}, inplace=True)

residence_flag_dict = {-1: 'Not reported', 1: 'Reported'}

residence_flag_column = []

for element in person_basic['Residence in the household (flag)']:
    for key in residence_flag_dict.keys():
        if element == key:
            residence_flag_column.append(residence_flag_dict[key])

person_basic['Residence in the household (flag)'] = residence_flag_column

person_basic[person_basic.columns[2:]].head()
# Out:
#   Individual cross factor value (flag) Month of birth Month of birth (flag)  \
# 0                             Reported              4              Reported
# 1                             Reported              2              Reported
# 2                             Reported              9              Reported
# 3                             Reported              4              Reported
# 4                             Reported             11              Reported
#
#    Year of birth Year of birth (flag)     Sex Sex (flag)  RB200  \
# 0           1949             Reported    Male   Reported      1
# 1           1951             Reported  Female   Reported      1
# 2           1947             Reported  Female   Reported      1
# 3           1959             Reported    Male   Reported      1
# 4           1965             Reported  Female   Reported      1
#
#   Residence in the household (flag) RB210  ...  RL040 RL040_F  RL050 RL050_F  \
# ...

# %%
person_basic['Residence in the household (flag)'].unique()
# Out:
# array(['Reported'], dtype=object)

# %%
person_basic.rename(columns={'RB200': 'Residence in the household'}, inplace=True)

residence_dict = {1: 'Currently living in the household', 2: 'Temporaly absent'}

residence_column = []

for element in person_basic['Residence in the household']:
    for key in residence_dict.keys():
        if element == key:
            residence_column.append(residence_dict[key])

person_basic['Residence in the household'] = residence_column

person_basic[person_basic.columns[3:]].head()
# Out:
#   Month of birth Month of birth (flag)  Year of birth Year of birth (flag)  \
# 0              4              Reported           1949             Reported
# 1              2              Reported           1951             Reported
# 2              9              Reported           1947             Reported
# 3              4              Reported           1959             Reported
# 4             11              Reported           1965             Reported
#
#       Sex Sex (flag)         Residence in the household  \
# 0    Male   Reported  Currently living in the household
# 1  Female   Reported  Currently living in the household
# 2  Female   Reported  Currently living in the household
# 3    Male   Reported  Currently living in the household
# 4  Female   Reported  Currently living in the household
#
#   Residence in the household (flag) RB210  RB210_F  ... RL040  RL040_F RL050  \
# 0                          Reported     3        1  ...             -2
# ...

# %%
person_basic.rename(columns={'RB210_F': 'Working status (flag)'}, inplace=True)

working_flag_dict = {-1: 'Not reported', 1: 'Reported'}

working_flag_column = []

for element in person_basic['Working status (flag)']:
    for key in working_flag_dict.keys():
        if element == key:
            working_flag_column.append(working_flag_dict[key])

person_basic['Working status (flag)'] = working_flag_column

person_basic[person_basic.columns[4:]].head()
# Out:
#   Month of birth (flag)  Year of birth Year of birth (flag)     Sex  \
# 0              Reported           1949             Reported    Male
# 1              Reported           1951             Reported  Female
# 2              Reported           1947             Reported  Female
# 3              Reported           1959             Reported    Male
# 4              Reported           1965             Reported  Female
#
#   Sex (flag)         Residence in the household  \
# 0   Reported  Currently living in the household
# 1   Reported  Currently living in the household
# 2   Reported  Currently living in the household
# 3   Reported  Currently living in the household
# 4   Reported  Currently living in the household
#
#   Residence in the household (flag) RB210 Working status (flag) RB220  ...  \
# 0                          Reported     3              Reported        ...
# 1                          Reported     4              Reported        ...
# ...

# %%
person_basic['Working status (flag)'].unique()
# Out:
# array(['Reported', 'Not reported'], dtype=object)

# %%
person_basic[person_basic['Working status (flag)'] == 'Not reported'].RB210.head()
# Out:
# 1358
# 29557
# 35634
# 37352
# 37353
# Name: RB210, dtype: object

# %%
person_basic.rename(columns={'RB210': 'Working status'}, inplace=True)

working_dict = {'1': 'Employed', '2': 'Unemployed', '3': 'Retired', '4': 'Other type of economic inactivity'}

working_column = []

for element in person_basic['Working status']:
    if element not in working_dict.keys():
        working_column.append('Not reported')
    else:
        for key in working_dict.keys():
            if element == key:
                working_column.append(working_dict[key])

person_basic['Working status'] = working_column

person_basic[person_basic.columns[5:]].head()
# Out:
#    Year of birth Year of birth (flag)     Sex Sex (flag)  \
# 0           1949             Reported    Male   Reported
# 1           1951             Reported  Female   Reported
# 2           1947             Reported  Female   Reported
# 3           1959             Reported    Male   Reported
# 4           1965             Reported  Female   Reported
#
#           Residence in the household Residence in the household (flag)  \
# 0  Currently living in the household                          Reported
# 1  Currently living in the household                          Reported
# 2  Currently living in the household                          Reported
# 3  Currently living in the household                          Reported
# 4  Currently living in the household                          Reported
#
#                       Working status Working status (flag) RB220  RB220_F  \
# 0                            Retired              Reported             -2
# ...

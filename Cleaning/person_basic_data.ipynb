# %%
import pandas as pd

# %%
person_basic = pd.read_csv(r'C:\Users\dvale\TFM\Data\person_basic.csv', low_memory=False) #Column 5 has different types

# %%
person_basic.head()
# Out:
#    RB010 RB020  RB030       RB050  RB050_F RB070  RB070_F  RB080  RB080_F  \
# 0   2019    ES    101   906.15830        1     4        1   1949        1
# 1   2019    ES    102   906.15830        1     2        1   1951        1
# 2   2019    ES    201  1227.68869        1     9        1   1947        1
# 3   2019    ES    202  1227.68869        1     4        1   1959        1
# 4   2019    ES    301  2559.35987        1    11        1   1965        1
#
#    RB090  ...  RL040  RL040_F  RL050 RL050_F  RL060 RL060_F  RL070 RL070_F  \
# 0      1  ...              -2             -2             -2             -2
# 1      2  ...              -2             -2             -2             -2
# 2      2  ...              -2             -2             -2             -2
# 3      1  ...              -2             -2             -2             -2
# 4      2  ...              -2             -2             -2             -2
#
#    vrLOWJOB vrEU2020
# 0         9        0
# 1         9        0
# ...

# %%
person_basic.rename(columns={'RB010': 'Year of survey'}, inplace=True)

person_basic[person_basic.columns[:10]].head()
# Out:
#    Year of survey RB020  RB030       RB050  RB050_F RB070  RB070_F  RB080  \
# 0            2019    ES    101   906.15830        1     4        1   1949
# 1            2019    ES    102   906.15830        1     2        1   1951
# 2            2019    ES    201  1227.68869        1     9        1   1947
# 3            2019    ES    202  1227.68869        1     4        1   1959
# 4            2019    ES    301  2559.35987        1    11        1   1965
#
#    RB080_F  RB090
# 0        1      1
# 1        1      2
# 2        1      2
# 3        1      1
# 4        1      2

# %%
person_basic.rename(columns={'RB020': 'Country'}, inplace=True)

person_basic[person_basic.columns[:10]].head()
# Out:
#    Year of survey Country  RB030       RB050  RB050_F RB070  RB070_F  RB080  \
# 0            2019      ES    101   906.15830        1     4        1   1949
# 1            2019      ES    102   906.15830        1     2        1   1951
# 2            2019      ES    201  1227.68869        1     9        1   1947
# 3            2019      ES    202  1227.68869        1     4        1   1959
# 4            2019      ES    301  2559.35987        1    11        1   1965
#
#    RB080_F  RB090
# 0        1      1
# 1        1      2
# 2        1      2
# 3        1      1
# 4        1      2

# %%
person_basic.rename(columns={'RB030': 'Person identification number'}, inplace=True)

person_basic[person_basic.columns[:10]].head()
# Out:
#    Year of survey Country  Person identification number       RB050  RB050_F  \
# 0            2019      ES                           101   906.15830        1
# 1            2019      ES                           102   906.15830        1
# 2            2019      ES                           201  1227.68869        1
# 3            2019      ES                           202  1227.68869        1
# 4            2019      ES                           301  2559.35987        1
#
#   RB070  RB070_F  RB080  RB080_F  RB090
# 0     4        1   1949        1      1
# 1     2        1   1951        1      2
# 2     9        1   1947        1      2
# 3     4        1   1959        1      1
# 4    11        1   1965        1      2

# %%
person_basic.rename(columns={'RB050': 'Individual cross factor value'}, inplace=True)

person_basic[person_basic.columns[:10]].head()
# Out:
#    Year of survey Country  Person identification number  \
# 0            2019      ES                           101
# 1            2019      ES                           102
# 2            2019      ES                           201
# 3            2019      ES                           202
# 4            2019      ES                           301
#
#    Individual cross factor value  RB050_F RB070  RB070_F  RB080  RB080_F  \
# 0                      906.15830        1     4        1   1949        1
# 1                      906.15830        1     2        1   1951        1
# 2                     1227.68869        1     9        1   1947        1
# 3                     1227.68869        1     4        1   1959        1
# 4                     2559.35987        1    11        1   1965        1
#
#    RB090
# 0      1
# 1      2
# 2      2
# 3      1
# 4      2

# %%
person_basic.rename(columns={'RB050_F': 'Individual cross factor value (flag)'}, inplace=True)

mapped_factor_flag = {-1: 'Not reported', 1: 'Reported'}

person_basic['Individual cross factor value (flag)'] = person_basic['Individual cross factor value (flag)'].map(mapped_factor_flag)

person_basic[person_basic.columns[:10]].head()
# Out:
#    Year of survey Country  Person identification number  \
# 0            2019      ES                           101
# 1            2019      ES                           102
# 2            2019      ES                           201
# 3            2019      ES                           202
# 4            2019      ES                           301
#
#    Individual cross factor value Individual cross factor value (flag) RB070  \
# 0                      906.15830                             Reported     4
# 1                      906.15830                             Reported     2
# 2                     1227.68869                             Reported     9
# 3                     1227.68869                             Reported     4
# 4                     2559.35987                             Reported    11
#
#    RB070_F  RB080  RB080_F  RB090
# 0        1   1949        1      1
# 1        1   1951        1      2
# 2        1   1947        1      2
# ...

# %%
person_basic.rename(columns={'RB070': 'Month of birth'}, inplace=True)

person_basic[person_basic.columns[:10]].head()
# Out:
#    Year of survey Country  Person identification number  \
# 0            2019      ES                           101
# 1            2019      ES                           102
# 2            2019      ES                           201
# 3            2019      ES                           202
# 4            2019      ES                           301
#
#    Individual cross factor value Individual cross factor value (flag)  \
# 0                      906.15830                             Reported
# 1                      906.15830                             Reported
# 2                     1227.68869                             Reported
# 3                     1227.68869                             Reported
# 4                     2559.35987                             Reported
#
#   Month of birth  RB070_F  RB080  RB080_F  RB090
# 0              4        1   1949        1      1
# 1              2        1   1951        1      2
# 2              9        1   1947        1      2
# ...

# %%
person_basic.rename(columns={'RB070_F': 'Month of birth (flag)'}, inplace=True)

mapped_birth_month_flag = {-1: 'Not reported', 1: 'Reported'}

person_basic['Month of birth (flag)'] = person_basic['Month of birth (flag)'].map(mapped_birth_month_flag)

person_basic[person_basic.columns[:10]].head()
# Out:
#    Year of survey Country  Person identification number  \
# 0            2019      ES                           101
# 1            2019      ES                           102
# 2            2019      ES                           201
# 3            2019      ES                           202
# 4            2019      ES                           301
#
#    Individual cross factor value Individual cross factor value (flag)  \
# 0                      906.15830                             Reported
# 1                      906.15830                             Reported
# 2                     1227.68869                             Reported
# 3                     1227.68869                             Reported
# 4                     2559.35987                             Reported
#
#   Month of birth Month of birth (flag)  RB080  RB080_F  RB090
# 0              4              Reported   1949        1      1
# 1              2              Reported   1951        1      2
# ...

# %%
person_basic.rename(columns={'RB080': 'Year of birth'}, inplace=True)

person_basic[person_basic.columns[1:11]].head()
# Out:
#   Country  Person identification number  Individual cross factor value  \
# 0      ES                           101                      906.15830
# 1      ES                           102                      906.15830
# 2      ES                           201                     1227.68869
# 3      ES                           202                     1227.68869
# 4      ES                           301                     2559.35987
#
#   Individual cross factor value (flag) Month of birth Month of birth (flag)  \
# 0                             Reported              4              Reported
# 1                             Reported              2              Reported
# 2                             Reported              9              Reported
# 3                             Reported              4              Reported
# 4                             Reported             11              Reported
#
#    Year of birth  RB080_F  RB090  RB090_F
# ...

# %%
person_basic.rename(columns={'RB080_F': 'Year of birth (flag)'}, inplace=True)

mapped_birth_year_flag = {-1: 'Not reported', 1: 'Reported'}

person_basic['Year of birth (flag)'] = person_basic['Year of birth (flag)'].map(mapped_birth_year_flag)

person_basic[person_basic.columns[2:12]].head()
# Out:
#    Person identification number  Individual cross factor value  \
# 0                           101                      906.15830
# 1                           102                      906.15830
# 2                           201                     1227.68869
# 3                           202                     1227.68869
# 4                           301                     2559.35987
#
#   Individual cross factor value (flag) Month of birth Month of birth (flag)  \
# 0                             Reported              4              Reported
# 1                             Reported              2              Reported
# 2                             Reported              9              Reported
# 3                             Reported              4              Reported
# 4                             Reported             11              Reported
#
#    Year of birth Year of birth (flag)  RB090  RB090_F  RB200
# 0           1949             Reported      1        1      1
# ...

# %%
person_basic.rename(columns={'RB090': 'Sex'}, inplace=True)

mapped_sex = {1: 'Male', 2: 'Female'}

person_basic.Sex = person_basic['Sex'].map(mapped_sex)

person_basic[person_basic.columns[3:13]].head()
# Out:
#    Individual cross factor value Individual cross factor value (flag)  \
# 0                      906.15830                             Reported
# 1                      906.15830                             Reported
# 2                     1227.68869                             Reported
# 3                     1227.68869                             Reported
# 4                     2559.35987                             Reported
#
#   Month of birth Month of birth (flag)  Year of birth Year of birth (flag)  \
# 0              4              Reported           1949             Reported
# 1              2              Reported           1951             Reported
# 2              9              Reported           1947             Reported
# 3              4              Reported           1959             Reported
# 4             11              Reported           1965             Reported
#
#       Sex  RB090_F  RB200  RB200_F
# 0    Male        1      1        1
# ...

# %%
person_basic.rename(columns={'RB090_F': 'Sex (flag)'}, inplace=True)

mapped_sex_flag = {-1: 'Not reported', 1: 'Reported'}

person_basic['Sex (flag)'] = person_basic['Sex (flag)'].map(mapped_sex_flag)

person_basic[person_basic.columns[4:14]].head()
# Out:
#   Individual cross factor value (flag) Month of birth Month of birth (flag)  \
# 0                             Reported              4              Reported
# 1                             Reported              2              Reported
# 2                             Reported              9              Reported
# 3                             Reported              4              Reported
# 4                             Reported             11              Reported
#
#    Year of birth Year of birth (flag)     Sex Sex (flag)  RB200  RB200_F RB210
# 0           1949             Reported    Male   Reported      1        1     3
# 1           1951             Reported  Female   Reported      1        1     4
# 2           1947             Reported  Female   Reported      1        1     4
# 3           1959             Reported    Male   Reported      1        1     3
# 4           1965             Reported  Female   Reported      1        1     4

# %%
person_basic.rename(columns={'RB200': 'Residence in the household'}, inplace=True)

mapped_residence = {1: 'Currently living in the household', 2: 'Temporaly absent'}

person_basic['Residence in the household'] = person_basic['Residence in the household'].map(mapped_residence)

person_basic[person_basic.columns[5:15]].head()
# Out:
#   Month of birth Month of birth (flag)  Year of birth Year of birth (flag)  \
# 0              4              Reported           1949             Reported
# 1              2              Reported           1951             Reported
# 2              9              Reported           1947             Reported
# 3              4              Reported           1959             Reported
# 4             11              Reported           1965             Reported
#
#       Sex Sex (flag)         Residence in the household  RB200_F RB210  \
# 0    Male   Reported  Currently living in the household        1     3
# 1  Female   Reported  Currently living in the household        1     4
# 2  Female   Reported  Currently living in the household        1     4
# 3    Male   Reported  Currently living in the household        1     3
# 4  Female   Reported  Currently living in the household        1     4
#
#    RB210_F
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
person_basic.rename(columns={'RB200_F': 'Residence in the household (flag)'}, inplace=True)

mapped_residence_flag = {-1: 'Not reported', 1: 'Reported'}

person_basic['Residence in the household (flag)'] = person_basic['Residence in the household (flag)'].map(mapped_residence_flag)

person_basic[person_basic.columns[6:16]].head()
# Out:
#   Month of birth (flag)  Year of birth Year of birth (flag)     Sex  \
# 0              Reported           1949             Reported    Male
# 1              Reported           1951             Reported  Female
# 2              Reported           1947             Reported  Female
# 3              Reported           1959             Reported    Male
# 4              Reported           1965             Reported  Female
#
#   Sex (flag)         Residence in the household  \
# 0   Reported  Currently living in the household
# 1   Reported  Currently living in the household
# 2   Reported  Currently living in the household
# 3   Reported  Currently living in the household
# 4   Reported  Currently living in the household
#
#   Residence in the household (flag) RB210  RB210_F RB220
# 0                          Reported     3        1
# 1                          Reported     4        1
# 2                          Reported     4        1
# ...

# %%
person_basic.rename(columns={'RB210': 'Working status'}, inplace=True)

mapped_status = {'1': 'Employed', '2': 'Unemployed', '3': 'Retired', '4': 'Other type of economic inactivity'}

person_basic['Working status'] = person_basic['Working status'].map(mapped_status)

person_basic[person_basic.columns[7:17]].head()
# Out:
#    Year of birth Year of birth (flag)     Sex Sex (flag)  \
# 0           1949             Reported    Male   Reported
# 1           1951             Reported  Female   Reported
# 2           1947             Reported  Female   Reported
# 3           1959             Reported    Male   Reported
# 4           1965             Reported  Female   Reported
#
#           Residence in the household Residence in the household (flag)  \
# 0  Currently living in the household                          Reported
# 1  Currently living in the household                          Reported
# 2  Currently living in the household                          Reported
# 3  Currently living in the household                          Reported
# 4  Currently living in the household                          Reported
#
#                       Working status  RB210_F RB220  RB220_F
# 0                            Retired        1             -2
# 1  Other type of economic inactivity        1             -2
# ...

# %%
person_basic.rename(columns={'RB210_F': 'Working status (flag)'}, inplace=True)

mapped_status_flag = {-1: 'Not reported', 1: 'Reported'}

person_basic['Working status (flag)'] = person_basic['Working status (flag)'].map(mapped_status_flag)

person_basic[person_basic.columns[8:18]].head()
# Out:
#   Year of birth (flag)     Sex Sex (flag)         Residence in the household  \
# 0             Reported    Male   Reported  Currently living in the household
# 1             Reported  Female   Reported  Currently living in the household
# 2             Reported  Female   Reported  Currently living in the household
# 3             Reported    Male   Reported  Currently living in the household
# 4             Reported  Female   Reported  Currently living in the household
#
#   Residence in the household (flag)                     Working status  \
# 0                          Reported                            Retired
# 1                          Reported  Other type of economic inactivity
# 2                          Reported  Other type of economic inactivity
# 3                          Reported                            Retired
# 4                          Reported  Other type of economic inactivity
#
#   Working status (flag) RB220  RB220_F RB230
# ...

# %%
person_basic.rename(columns={'RB220': 'Father identification number'}, inplace=True)

person_basic[person_basic.columns[9:19]].head()
# Out:
#       Sex Sex (flag)         Residence in the household  \
# 0    Male   Reported  Currently living in the household
# 1  Female   Reported  Currently living in the household
# 2  Female   Reported  Currently living in the household
# 3    Male   Reported  Currently living in the household
# 4  Female   Reported  Currently living in the household
#
#   Residence in the household (flag)                     Working status  \
# 0                          Reported                            Retired
# 1                          Reported  Other type of economic inactivity
# 2                          Reported  Other type of economic inactivity
# 3                          Reported                            Retired
# 4                          Reported  Other type of economic inactivity
#
#   Working status (flag) Father identification number  RB220_F RB230  RB230_F
# 0              Reported                                    -2             -2
# ...

# %%
person_basic.rename(columns={'RB220_F': 'Father identification number (flag)'}, inplace=True)

mapped_father_id_flag = {-2: 'Does not belong to household/Does not exist', -1: 'Not reported', 1: 'Reported'}

person_basic['Father identification number (flag)'] = person_basic['Father identification number (flag)'].map(mapped_father_id_flag)

person_basic[person_basic.columns[10:20]].head()
# Out:
#   Sex (flag)         Residence in the household  \
# 0   Reported  Currently living in the household
# 1   Reported  Currently living in the household
# 2   Reported  Currently living in the household
# 3   Reported  Currently living in the household
# 4   Reported  Currently living in the household
#
#   Residence in the household (flag)                     Working status  \
# 0                          Reported                            Retired
# 1                          Reported  Other type of economic inactivity
# 2                          Reported  Other type of economic inactivity
# 3                          Reported                            Retired
# 4                          Reported  Other type of economic inactivity
#
#   Working status (flag) Father identification number  \
# 0              Reported
# 1              Reported
# 2              Reported
# 3              Reported
# 4              Reported
#
# ...

# %%
person_basic.rename(columns={'RB230': 'Mother identification number'}, inplace=True)

person_basic[person_basic.columns[11:21]].head()
# Out:
#           Residence in the household Residence in the household (flag)  \
# 0  Currently living in the household                          Reported
# 1  Currently living in the household                          Reported
# 2  Currently living in the household                          Reported
# 3  Currently living in the household                          Reported
# 4  Currently living in the household                          Reported
#
#                       Working status Working status (flag)  \
# 0                            Retired              Reported
# 1  Other type of economic inactivity              Reported
# 2  Other type of economic inactivity              Reported
# 3                            Retired              Reported
# 4  Other type of economic inactivity              Reported
#
#   Father identification number          Father identification number (flag)  \
# 0                               Does not belong to household/Does not exist
# ...

# %%
person_basic.rename(columns={'RB230_F': 'Mother identification number (flag)'}, inplace=True)

mapped_mother_id_flag = {-2: 'Does not belong to household/Does not exist', -1: 'Not reported', 1: 'Reported'}

person_basic['Mother identification number (flag)'] = person_basic['Mother identification number (flag)'].map(mapped_mother_id_flag)

person_basic[person_basic.columns[12:21]].head()
# Out:
#   Residence in the household (flag)                     Working status  \
# 0                          Reported                            Retired
# 1                          Reported  Other type of economic inactivity
# 2                          Reported  Other type of economic inactivity
# 3                          Reported                            Retired
# 4                          Reported  Other type of economic inactivity
#
#   Working status (flag) Father identification number  \
# 0              Reported
# 1              Reported
# 2              Reported
# 3              Reported
# 4              Reported
#
#            Father identification number (flag) Mother identification number  \
# 0  Does not belong to household/Does not exist
# 1  Does not belong to household/Does not exist
# 2  Does not belong to household/Does not exist
# 3  Does not belong to household/Does not exist
# 4  Does not belong to household/Does not exist
#
# ...

# %%
person_basic.rename(columns={'RB240': 'Partner identification number'}, inplace=True)

person_basic[person_basic.columns[13:23]].head()
# Out:
#                       Working status Working status (flag)  \
# 0                            Retired              Reported
# 1  Other type of economic inactivity              Reported
# 2  Other type of economic inactivity              Reported
# 3                            Retired              Reported
# 4  Other type of economic inactivity              Reported
#
#   Father identification number          Father identification number (flag)  \
# 0                               Does not belong to household/Does not exist
# 1                               Does not belong to household/Does not exist
# 2                               Does not belong to household/Does not exist
# 3                               Does not belong to household/Does not exist
# 4                               Does not belong to household/Does not exist
#
#   Mother identification number          Mother identification number (flag)  \
# ...

# %%
person_basic.rename(columns={'RB240_F': 'Partner identification number (flag)'}, inplace=True)

mapped_partner_id_flag = {-2: 'Does not belong to household/Does not exist', -1: 'Not reported', 1: 'Reported'}

person_basic['Partner identification number (flag)'] = person_basic['Partner identification number (flag)'].map(mapped_partner_id_flag)

person_basic[person_basic.columns[14:24]].head()
# Out:
#   Working status (flag) Father identification number  \
# 0              Reported
# 1              Reported
# 2              Reported
# 3              Reported
# 4              Reported
#
#            Father identification number (flag) Mother identification number  \
# 0  Does not belong to household/Does not exist
# 1  Does not belong to household/Does not exist
# 2  Does not belong to household/Does not exist
# 3  Does not belong to household/Does not exist
# 4  Does not belong to household/Does not exist
#
#            Mother identification number (flag) Partner identification number  \
# 0  Does not belong to household/Does not exist                           102
# 1  Does not belong to household/Does not exist                           101
# 2  Does not belong to household/Does not exist                           202
# 3  Does not belong to household/Does not exist                           201
# 4  Does not belong to household/Does not exist
#
# ...

# %%
person_basic.rename(columns={'RL010': 'Hours per week in kindergarden'}, inplace=True)

person_basic[person_basic.columns[15:25]].head()
# Out:
#   Father identification number          Father identification number (flag)  \
# 0                               Does not belong to household/Does not exist
# 1                               Does not belong to household/Does not exist
# 2                               Does not belong to household/Does not exist
# 3                               Does not belong to household/Does not exist
# 4                               Does not belong to household/Does not exist
#
#   Mother identification number          Mother identification number (flag)  \
# 0                               Does not belong to household/Does not exist
# 1                               Does not belong to household/Does not exist
# 2                               Does not belong to household/Does not exist
# 3                               Does not belong to household/Does not exist
# 4                               Does not belong to household/Does not exist
#
# ...

# %%
person_basic.rename(columns={'RL010_F': 'Hours per week in kindergarden (flag)'}, inplace=True)

mapped_kindergarden_flag = {-2: 'Does not apply', -1: 'Not reported', 1: 'Reported'}

person_basic['Hours per week in kindergarden (flag)'] = person_basic['Hours per week in kindergarden (flag)'].map(mapped_kindergarden_flag)

person_basic[person_basic.columns[16:26]].head()
# Out:
#            Father identification number (flag) Mother identification number  \
# 0  Does not belong to household/Does not exist
# 1  Does not belong to household/Does not exist
# 2  Does not belong to household/Does not exist
# 3  Does not belong to household/Does not exist
# 4  Does not belong to household/Does not exist
#
#            Mother identification number (flag) Partner identification number  \
# 0  Does not belong to household/Does not exist                           102
# 1  Does not belong to household/Does not exist                           101
# 2  Does not belong to household/Does not exist                           202
# 3  Does not belong to household/Does not exist                           201
# 4  Does not belong to household/Does not exist
#
#           Partner identification number (flag) Hours per week in kindergarden  \
# 0                                     Reported
# 1                                     Reported
# ...

# %%
person_basic.rename(columns={'RL020': 'Hours per week in primary or secondary school'}, inplace=True)

person_basic[person_basic.columns[17:27]].head()
# Out:
#   Mother identification number          Mother identification number (flag)  \
# 0                               Does not belong to household/Does not exist
# 1                               Does not belong to household/Does not exist
# 2                               Does not belong to household/Does not exist
# 3                               Does not belong to household/Does not exist
# 4                               Does not belong to household/Does not exist
#
#   Partner identification number         Partner identification number (flag)  \
# 0                           102                                     Reported
# 1                           101                                     Reported
# 2                           202                                     Reported
# 3                           201                                     Reported
# 4                                Does not belong to household/Does not exist
#
# ...

# %%
person_basic.rename(columns={'RL020_F': 'Hours per week in primary or secondary school (flag)'}, inplace=True)

mapped_school_flag = {-2: 'Does not apply', -1: 'Not reported', 1: 'Reported'}

person_basic['Hours per week in primary or secondary school (flag)'] = person_basic['Hours per week in primary or secondary school (flag)'].map(mapped_school_flag)

person_basic[person_basic.columns[18:28]].head()
# Out:
#            Mother identification number (flag) Partner identification number  \
# 0  Does not belong to household/Does not exist                           102
# 1  Does not belong to household/Does not exist                           101
# 2  Does not belong to household/Does not exist                           202
# 3  Does not belong to household/Does not exist                           201
# 4  Does not belong to household/Does not exist
#
#           Partner identification number (flag) Hours per week in kindergarden  \
# 0                                     Reported
# 1                                     Reported
# 2                                     Reported
# 3                                     Reported
# 4  Does not belong to household/Does not exist
#
#   Hours per week in kindergarden (flag)  \
# 0                        Does not apply
# 1                        Does not apply
# 2                        Does not apply
# 3                        Does not apply
# ...

# %%
person_basic.rename(columns={'RL030': 'Hours per week in in after school care'}, inplace=True)

person_basic[person_basic.columns[19:29]].head()
# Out:
#   Partner identification number         Partner identification number (flag)  \
# 0                           102                                     Reported
# 1                           101                                     Reported
# 2                           202                                     Reported
# 3                           201                                     Reported
# 4                                Does not belong to household/Does not exist
#
#   Hours per week in kindergarden Hours per week in kindergarden (flag)  \
# 0                                                       Does not apply
# 1                                                       Does not apply
# 2                                                       Does not apply
# 3                                                       Does not apply
# 4                                                       Does not apply
#
#   Hours per week in primary or secondary school  \
# 0
# 1
# 2
# 3
# 4
#
# ...

# %%
person_basic.rename(columns={'RL030_F': 'Hours per week in after school care (flag)'}, inplace=True)

mapped_after_school_flag = {-2: 'Does not apply', -1: 'Not reported', 1: 'Reported'}

person_basic['Hours per week in after school care (flag)'] = person_basic['Hours per week in after school care (flag)'].map(mapped_after_school_flag)

person_basic[person_basic.columns[20:30]].head()
# Out:
#           Partner identification number (flag) Hours per week in kindergarden  \
# 0                                     Reported
# 1                                     Reported
# 2                                     Reported
# 3                                     Reported
# 4  Does not belong to household/Does not exist
#
#   Hours per week in kindergarden (flag)  \
# 0                        Does not apply
# 1                        Does not apply
# 2                        Does not apply
# 3                        Does not apply
# 4                        Does not apply
#
#   Hours per week in primary or secondary school  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in primary or secondary school (flag)  \
# 0                                     Does not apply
# 1                                     Does not apply
# 2                                     Does not apply
# 3                                     Does not apply
# 4                                     Does not apply
#
# ...

# %%
person_basic.rename(columns={'RL040': 'Hours per week in other care centers'}, inplace=True)

person_basic[person_basic.columns[21:31]].head()
# Out:
#   Hours per week in kindergarden Hours per week in kindergarden (flag)  \
# 0                                                       Does not apply
# 1                                                       Does not apply
# 2                                                       Does not apply
# 3                                                       Does not apply
# 4                                                       Does not apply
#
#   Hours per week in primary or secondary school  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in primary or secondary school (flag)  \
# 0                                     Does not apply
# 1                                     Does not apply
# 2                                     Does not apply
# 3                                     Does not apply
# 4                                     Does not apply
#
#   Hours per week in in after school care  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in after school care (flag)  \
# ...

# %%
person_basic.rename(columns={'RL040_F': 'Hours per week in other care centers (flag)'}, inplace=True)

mapped_other_care_flag = {-2: 'Does not apply', -1: 'Not reported', 1: 'Reported'}

person_basic['Hours per week in other care centers (flag)'] = person_basic['Hours per week in other care centers (flag)'].map(mapped_other_care_flag)

person_basic[person_basic.columns[22:32]].head()
# Out:
#   Hours per week in kindergarden (flag)  \
# 0                        Does not apply
# 1                        Does not apply
# 2                        Does not apply
# 3                        Does not apply
# 4                        Does not apply
#
#   Hours per week in primary or secondary school  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in primary or secondary school (flag)  \
# 0                                     Does not apply
# 1                                     Does not apply
# 2                                     Does not apply
# 3                                     Does not apply
# 4                                     Does not apply
#
#   Hours per week in in after school care  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in after school care (flag)  \
# 0                             Does not apply
# 1                             Does not apply
# 2                             Does not apply
# 3                             Does not apply
# ...

# %%
person_basic.rename(columns={'RL050': 'Hours per week with paid caregiver'}, inplace=True)

person_basic[person_basic.columns[23:33]].head()
# Out:
#   Hours per week in primary or secondary school  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in primary or secondary school (flag)  \
# 0                                     Does not apply
# 1                                     Does not apply
# 2                                     Does not apply
# 3                                     Does not apply
# 4                                     Does not apply
#
#   Hours per week in in after school care  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in after school care (flag)  \
# 0                             Does not apply
# 1                             Does not apply
# 2                             Does not apply
# 3                             Does not apply
# 4                             Does not apply
#
#   Hours per week in other care centers  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in other care centers (flag)  \
# 0                              Does not apply
# 1                              Does not apply
# ...

# %%
person_basic.rename(columns={'RL050_F': 'Hours per week with paid caregiver (flag)'}, inplace=True)

mapped_paid_caregiver_flag = {-2: 'Does not apply', -1: 'Not reported', 1: 'Reported'}

person_basic['Hours per week with paid caregiver (flag)'] = person_basic['Hours per week with paid caregiver (flag)'].map(mapped_paid_caregiver_flag)

person_basic[person_basic.columns[24:34]].head()
# Out:
#   Hours per week in primary or secondary school (flag)  \
# 0                                     Does not apply
# 1                                     Does not apply
# 2                                     Does not apply
# 3                                     Does not apply
# 4                                     Does not apply
#
#   Hours per week in in after school care  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in after school care (flag)  \
# 0                             Does not apply
# 1                             Does not apply
# 2                             Does not apply
# 3                             Does not apply
# 4                             Does not apply
#
#   Hours per week in other care centers  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in other care centers (flag)  \
# 0                              Does not apply
# 1                              Does not apply
# 2                              Does not apply
# ...

# %%
person_basic.rename(columns={'RL060': 'Hours per week with unpaid caregiver'}, inplace=True)

person_basic[person_basic.columns[25:35]].head()
# Out:
#   Hours per week in in after school care  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in after school care (flag)  \
# 0                             Does not apply
# 1                             Does not apply
# 2                             Does not apply
# 3                             Does not apply
# 4                             Does not apply
#
#   Hours per week in other care centers  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in other care centers (flag)  \
# 0                              Does not apply
# 1                              Does not apply
# 2                              Does not apply
# 3                              Does not apply
# 4                              Does not apply
#
#   Hours per week with paid caregiver  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week with paid caregiver (flag)  \
# 0                            Does not apply
# 1                            Does not apply
# 2                            Does not apply
# ...

# %%
person_basic.rename(columns={'RL060_F': 'Hours per week with unpaid caregiver (flag)'}, inplace=True)

mapped_unpaid_caregiver_flag = {-2: 'Does not apply', -1: 'Not reported', 1: 'Reported'}

person_basic['Hours per week with unpaid caregiver (flag)'] = person_basic['Hours per week with unpaid caregiver (flag)'].map(mapped_unpaid_caregiver_flag)

person_basic[person_basic.columns[26:36]].head()
# Out:
#   Hours per week in after school care (flag)  \
# 0                             Does not apply
# 1                             Does not apply
# 2                             Does not apply
# 3                             Does not apply
# 4                             Does not apply
#
#   Hours per week in other care centers  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in other care centers (flag)  \
# 0                              Does not apply
# 1                              Does not apply
# 2                              Does not apply
# 3                              Does not apply
# 4                              Does not apply
#
#   Hours per week with paid caregiver  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week with paid caregiver (flag)  \
# 0                            Does not apply
# 1                            Does not apply
# 2                            Does not apply
# 3                            Does not apply
# 4                            Does not apply
#
# ...

# %%
person_basic.rename(columns={'RL070': 'Child care cross factor value'}, inplace=True)

person_basic[person_basic.columns[27:37]].head()
# Out:
#   Hours per week in other care centers  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in other care centers (flag)  \
# 0                              Does not apply
# 1                              Does not apply
# 2                              Does not apply
# 3                              Does not apply
# 4                              Does not apply
#
#   Hours per week with paid caregiver  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week with paid caregiver (flag)  \
# 0                            Does not apply
# 1                            Does not apply
# 2                            Does not apply
# 3                            Does not apply
# 4                            Does not apply
#
#   Hours per week with unpaid caregiver  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week with unpaid caregiver (flag) Child care cross factor value  \
# 0                              Does not apply
# 1                              Does not apply
# 2                              Does not apply
# ...

# %%
person_basic.rename(columns={'RL070_F': 'Child care cross factor value (flag)'}, inplace=True)

mapped_child_factor_flag = {-2: 'Does not apply', 1: 'Reported'}

person_basic['Child care cross factor value (flag)'] = person_basic['Child care cross factor value (flag)'].map(mapped_child_factor_flag)

person_basic[person_basic.columns[27:]].head()
# Out:
#   Hours per week in other care centers  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in other care centers (flag)  \
# 0                              Does not apply
# 1                              Does not apply
# 2                              Does not apply
# 3                              Does not apply
# 4                              Does not apply
#
#   Hours per week with paid caregiver  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week with paid caregiver (flag)  \
# 0                            Does not apply
# 1                            Does not apply
# 2                            Does not apply
# 3                            Does not apply
# 4                            Does not apply
#
#   Hours per week with unpaid caregiver  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week with unpaid caregiver (flag) Child care cross factor value  \
# 0                              Does not apply
# 1                              Does not apply
# 2                              Does not apply
# ...

# %%
person_basic.rename(columns={'vrLOWJOB': 'Living in household with low employement level'}, inplace=True)

mapped_low_employement = {1: 'Yes', 0: 'No', 9: 'Does not apply'}

person_basic['Living in household with low employement level'] = person_basic['Living in household with low employement level'].map(mapped_low_employement)

person_basic[person_basic.columns[27:]].head()
# Out:
#   Hours per week in other care centers  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in other care centers (flag)  \
# 0                              Does not apply
# 1                              Does not apply
# 2                              Does not apply
# 3                              Does not apply
# 4                              Does not apply
#
#   Hours per week with paid caregiver  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week with paid caregiver (flag)  \
# 0                            Does not apply
# 1                            Does not apply
# 2                            Does not apply
# 3                            Does not apply
# 4                            Does not apply
#
#   Hours per week with unpaid caregiver  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week with unpaid caregiver (flag) Child care cross factor value  \
# 0                              Does not apply
# 1                              Does not apply
# 2                              Does not apply
# ...

# %%
person_basic.rename(columns={'vrEU2020': 'Living in household under risk of poverty'}, inplace=True)

mapped_risk_poverty = {1: 'Yes', 0: 'No'}

person_basic['Living in household under risk of poverty'] = person_basic['Living in household under risk of poverty'].map(mapped_risk_poverty)

person_basic[person_basic.columns[27:]].head()
# Out:
#   Hours per week in other care centers  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week in other care centers (flag)  \
# 0                              Does not apply
# 1                              Does not apply
# 2                              Does not apply
# 3                              Does not apply
# 4                              Does not apply
#
#   Hours per week with paid caregiver  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week with paid caregiver (flag)  \
# 0                            Does not apply
# 1                            Does not apply
# 2                            Does not apply
# 3                            Does not apply
# 4                            Does not apply
#
#   Hours per week with unpaid caregiver  \
# 0
# 1
# 2
# 3
# 4
#
#   Hours per week with unpaid caregiver (flag) Child care cross factor value  \
# 0                              Does not apply
# 1                              Does not apply
# 2                              Does not apply
# ...

# %%
person_basic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39852 entries, 0 to 39851
# Data columns (total 37 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Year of survey                                                  39852 non-null  int64
#  1   Country                                                         39852 non-null  object
#  2   Person identification number                                    39852 non-null  int64
#  3   Individual cross factor value                                   39852 non-null  float64
#  4   Individual cross factor value (flag)                            39852 non-null  object
#  5   Month of birth                                                  39852 non-null  object
#  6   Month of birth (flag)                                           39852 non-null  object
# ...
